# %%
import pandas as pd

# %%
states = pd.read_csv('data/states.csv')

# %%
states[['State','Abbrev']].value_counts()
# Out:
# State                 Abbrev
# Alabama               Ala.      1
# Pennsylvania          Pa.       1
# Nevada                Nev.      1
# New Hampshire         N.H.      1
# New Jersey            N.J.      1
# New Mexico            N.M.      1
# New York              N.Y.      1
# North Carolina        N.C.      1
# North Dakota          N.D.      1
# Ohio                  Ohio      1
# Oklahoma              Okla.     1
# Oregon                Ore.      1
# Rhode Island          R.I.      1
# Montana               Mont.     1
# South Carolina        S.C.      1
# South Dakota          S.D.      1
# Tennessee             Tenn.     1
# Texas                 Tex.      1
# Utah                  Utah      1
# Vermont               Vt.       1
# Virginia              Va.       1
# Washington            Wash.     1
# West Virginia         W.Va.     1
# Wisconsin             Wis.      1
# Nebraska              Nebr.     1
# Missouri              Mo.       1
# ...

# %%
states
# Out:
#                    State  Abbrev Code
# 0                Alabama    Ala.   AL
# 1                 Alaska  Alaska   AK
# 2                Arizona   Ariz.   AZ
# 3               Arkansas    Ark.   AR
# 4             California  Calif.   CA
# 5               Colorado   Colo.   CO
# 6            Connecticut   Conn.   CT
# 7               Delaware    Del.   DE
# 8   District of Columbia    D.C.   DC
# 9                Florida    Fla.   FL
# 10               Georgia     Ga.   GA
# 11                Hawaii  Hawaii   HI
# 12                 Idaho   Idaho   ID
# 13              Illinois    Ill.   IL
# 14               Indiana    Ind.   IN
# 15                  Iowa    Iowa   IA
# 16                Kansas   Kans.   KS
# 17              Kentucky     Ky.   KY
# 18             Louisiana     La.   LA
# 19                 Maine   Maine   ME
# 20              Maryland     Md.   MD
# 21         Massachusetts   Mass.   MA
# 22              Michigan   Mich.   MI
# 23             Minnesota   Minn.   MN
# ...

# %%
states.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   State   51 non-null     object
#  1   Abbrev  51 non-null     object
#  2   Code    51 non-null     object
# dtypes: object(3)
# memory usage: 1.3+ KB

# %%
#it shows the data types 
states.dtypes
# Out:
# State     object
# Abbrev    object
# Code      object
# dtype: object

# %%
states.columns
# Out:
# Index(['State', 'Abbrev', 'Code'], dtype='object')

# %%
houses =pd.read_csv('data/kc_house_data.csv')

# %%
houses
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
houses['bedrooms'].value_counts()
# Out:
# 3     9824
# 4     6882
# 2     2760
# 5     1601
# 6      272
# 1      199
# 7       38
# 0       13
# 8       13
# 9        6
# 10       3
# 11       1
# 33       1
# Name: bedrooms, dtype: int64

# %%
houses.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
len(houses)
# Out:
# 21613

# %%
houses.shape
# Out:
# (21613, 21)

# %%
houses.size
# Out:
# 453873

# %%
pd.options.display.min_rows = 50

# %%
houses.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
houses.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
numh=houses.tail()
numh
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 21608         1530      1131     3.0           0     0  ...      8
# 21609         2310      5813     2.0           0     0  ...      8
# 21610         1020      1350     2.0           0     0  ...      7
# 21611         1600      2388     2.0           0     0  ...      8
# 21612         1020      1076     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 21608        1530              0      2009             0    98103  47.6993
# ...

# %%
type(numh)
# Out:
# pandas.core.frame.DataFrame

# %%
houses.head(50)
# Out:
#             id             date      price  bedrooms  bathrooms  sqft_living  \
# 0   7129300520  20141013T000000   221900.0         3       1.00         1180
# 1   6414100192  20141209T000000   538000.0         3       2.25         2570
# 2   5631500400  20150225T000000   180000.0         2       1.00          770
# 3   2487200875  20141209T000000   604000.0         4       3.00         1960
# 4   1954400510  20150218T000000   510000.0         3       2.00         1680
# 5   7237550310  20140512T000000  1225000.0         4       4.50         5420
# 6   1321400060  20140627T000000   257500.0         3       2.25         1715
# 7   2008000270  20150115T000000   291850.0         3       1.50         1060
# 8   2414600126  20150415T000000   229500.0         3       1.00         1780
# 9   3793500160  20150312T000000   323000.0         3       2.50         1890
# 10  1736800520  20150403T000000   662500.0         3       2.50         3560
# ...

# %%
converted =pd.read_csv('data/tr.csv')
converted
# Out:
#    ID        Start time   Completion time      Email  Name Gender Age range  \
# 0   1   4/28/23 9:26:46   4/28/23 9:34:48  anonymous   NaN   Male     26-30
# 1   2   4/28/23 9:21:34   4/28/23 9:38:04  anonymous   NaN   Male     36-40
# 2   3   4/28/23 9:36:07   4/28/23 9:41:00  anonymous   NaN   Male     26-30
# 3   4  4/28/23 11:22:09  4/28/23 11:28:48  anonymous   NaN   Male     18-25
#
#                            Educational Qualification  \
# 0                            Undergraduate - Diploma
# 1  Postgraduate - Master's Degree or Doctorate De...
# 2                            Undergraduate - Diploma
# 3                  Undergraduate - Bachelor's Degree
#
#   How long have you been employed by the company?  \
# 0                               Less than 5 years
# 1                                       10+ years
# 2                               Less than 5 years
# 3                               Less than 5 years
#
# ...

# %%
converted.head(8)
# Out:
#    ID        Start time   Completion time      Email  Name Gender Age range  \
# 0   1   4/28/23 9:26:46   4/28/23 9:34:48  anonymous   NaN   Male     26-30
# 1   2   4/28/23 9:21:34   4/28/23 9:38:04  anonymous   NaN   Male     36-40
# 2   3   4/28/23 9:36:07   4/28/23 9:41:00  anonymous   NaN   Male     26-30
# 3   4  4/28/23 11:22:09  4/28/23 11:28:48  anonymous   NaN   Male     18-25
#
#                            Educational Qualification  \
# 0                            Undergraduate - Diploma
# 1  Postgraduate - Master's Degree or Doctorate De...
# 2                            Undergraduate - Diploma
# 3                  Undergraduate - Bachelor's Degree
#
#   How long have you been employed by the company?  \
# 0                               Less than 5 years
# 1                                       10+ years
# 2                               Less than 5 years
# 3                               Less than 5 years
#
# ...

# %%
converted
# Out:
#    ID        Start time   Completion time      Email  Name Gender Age range  \
# 0   1   4/28/23 9:26:46   4/28/23 9:34:48  anonymous   NaN   Male     26-30
# 1   2   4/28/23 9:21:34   4/28/23 9:38:04  anonymous   NaN   Male     36-40
# 2   3   4/28/23 9:36:07   4/28/23 9:41:00  anonymous   NaN   Male     26-30
# 3   4  4/28/23 11:22:09  4/28/23 11:28:48  anonymous   NaN   Male     18-25
#
#                            Educational Qualification  \
# 0                            Undergraduate - Diploma
# 1  Postgraduate - Master's Degree or Doctorate De...
# 2                            Undergraduate - Diploma
# 3                  Undergraduate - Bachelor's Degree
#
#   How long have you been employed by the company?  \
# 0                               Less than 5 years
# 1                                       10+ years
# 2                               Less than 5 years
# 3                               Less than 5 years
#
# ...

# %%
houses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
converted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 32 columns):
#  #   Column                                                                                                                                      Non-Null Count  Dtype
# ---  ------                                                                                                                                      --------------  -----
#  0   ID                                                                                                                                          4 non-null      int64
#  1   Start time                                                                                                                                  4 non-null      object
#  2   Completion time                                                                                                                             4 non-null      object
# ...

# %%
houses
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000   221900.0         3       1.00
# 1      6414100192  20141209T000000   538000.0         3       2.25
# 2      5631500400  20150225T000000   180000.0         2       1.00
# 3      2487200875  20141209T000000   604000.0         4       3.00
# 4      1954400510  20150218T000000   510000.0         3       2.00
# 5      7237550310  20140512T000000  1225000.0         4       4.50
# 6      1321400060  20140627T000000   257500.0         3       2.25
# 7      2008000270  20150115T000000   291850.0         3       1.50
# 8      2414600126  20150415T000000   229500.0         3       1.00
# 9      3793500160  20150312T000000   323000.0         3       2.50
# 10     1736800520  20150403T000000   662500.0         3       2.50
# 11     9212900260  20140527T000000   468000.0         2       1.00
# 12      114101516  20140528T000000   310000.0         3       1.00
# ...

# %%
titanic=pd.read_csv('data/titanic.csv')
titanic.head(20)
# Out:
#     pclass  survived                                               name  \
# 0        1         1                      Allen, Miss. Elisabeth Walton
# 1        1         1                     Allison, Master. Hudson Trevor
# 2        1         0                       Allison, Miss. Helen Loraine
# 3        1         0               Allison, Mr. Hudson Joshua Creighton
# 4        1         0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5        1         1                                Anderson, Mr. Harry
# 6        1         1                  Andrews, Miss. Kornelia Theodosia
# 7        1         0                             Andrews, Mr. Thomas Jr
# 8        1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9        1         0                            Artagaveytia, Mr. Ramon
# 10       1         0                             Astor, Col. John Jacob
# 11       1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# ...

# %%
netflix= pd.read_csv('data/netflix_titles.csv', sep ='|',index_col=0)
netflix
# Out:
#      show_id     type                                              title  \
# 0         s1    Movie                               Dick Johnson Is Dead
# 1         s2  TV Show                                      Blood & Water
# 2         s3  TV Show                                          Ganglands
# 3         s4  TV Show                              Jailbirds New Orleans
# 4         s5  TV Show                                       Kota Factory
# 5         s6  TV Show                                      Midnight Mass
# 6         s7    Movie                   My Little Pony: A New Generation
# 7         s8    Movie                                            Sankofa
# 8         s9  TV Show                      The Great British Baking Show
# 9        s10    Movie                                       The Starling
# 10       s11  TV Show                Vendetta: Truth, Lies and The Mafia
# 11       s12  TV Show                                   Bangkok Breaking
# ...

# %%
netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 894.5+ KB

# %% [markdown]
# # THIS IS WHHEN YOU WANNA CHANGE THE FEILD NAME

# %%
columns_change=['Dennis','hans','justin','poto','danni','OT']
pd.read_csv('data/nst-est2020.csv', names=columns_change, header=0)
# Out:
#                                                                                                                    Dennis  \
# 10 0 0 0  United States        308745538 308758105 309327143 311583481 313877662 316059947 318386329 320738994  323071755
# 20 1 0 0  Northeast Region     55317240  55318414  55380764  55608318  55782661  55912775  56021339  56052790    56063777
#    2 0 0  Midwest Region       66927001  66929737  66975328  67164092  67348275  67576524  67765576  67885682    68018175
#    3 0 0  South Region         114555744 114563042 114869421 116019483 117264196 118397213 119666248 121049223  122419547
#    4 0 0  West Region          71945553  71946912  72101630  72791588  73482530  74173435  74933166  75751299    76570256
# 40 3 6 1  Alabama              4779736   4780118   4785514   4799642   4816632   4831586   4843737   4854803      4866824
#    4 9 2  Alaska               710231    710246    713982    722349    730810    737626    737075    738430        742575
# ...

# %% [markdown]
# # BASIC DATAFAMES
# • Sum
# • Min
# • Mах
# • median
# • mode
# • mean
# • count
# • describe

# %%
hs= pd.read_csv('data/kc_house_data.csv')
hs
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000   221900.0         3       1.00
# 1      6414100192  20141209T000000   538000.0         3       2.25
# 2      5631500400  20150225T000000   180000.0         2       1.00
# 3      2487200875  20141209T000000   604000.0         4       3.00
# 4      1954400510  20150218T000000   510000.0         3       2.00
# 5      7237550310  20140512T000000  1225000.0         4       4.50
# 6      1321400060  20140627T000000   257500.0         3       2.25
# 7      2008000270  20150115T000000   291850.0         3       1.50
# 8      2414600126  20150415T000000   229500.0         3       1.00
# 9      3793500160  20150312T000000   323000.0         3       2.50
# 10     1736800520  20150403T000000   662500.0         3       2.50
# 11     9212900260  20140527T000000   468000.0         2       1.00
# 12      114101516  20140528T000000   310000.0         3       1.00
# ...

# %%
hs.min()
# Out:
# id                       1000102
# date             20140502T000000
# price                    75000.0
# bedrooms                       0
# bathrooms                    0.0
# sqft_living                  290
# sqft_lot                     520
# floors                       1.0
# waterfront                     0
# view                           0
# condition                      1
# grade                          1
# sqft_above                   290
# sqft_basement                  0
# yr_built                    1900
# yr_renovated                   0
# zipcode                    98001
# lat                      47.1559
# long                    -122.519
# sqft_living15                399
# sqft_lot15                   651
# dtype: object

# %%
hs.max()
# Out:
# id                    9900000190
# date             20150527T000000
# price                  7700000.0
# bedrooms                      33
# bathrooms                    8.0
# sqft_living                13540
# sqft_lot                 1651359
# floors                       3.5
# waterfront                     1
# view                           4
# condition                      5
# grade                         13
# sqft_above                  9410
# sqft_basement               4820
# yr_built                    2015
# yr_renovated                2015
# zipcode                    98199
# lat                      47.7776
# long                    -121.315
# sqft_living15               6210
# sqft_lot15                871200
# dtype: object

# %%
type(hs.max())
# Out:
# pandas.core.series.Series

# %%
hs.sum()
# Out:
# id                                                  98994056770455
# date             20141013T00000020141209T00000020150225T0000002...
# price                                                11672925008.0
# bedrooms                                                     72854
# bathrooms                                                 45706.25
# sqft_living                                               44952873
# sqft_lot                                                 326506890
# floors                                                     32296.5
# waterfront                                                     163
# view                                                          5064
# condition                                                    73688
# grade                                                       165488
# sqft_above                                                38652488
# sqft_basement                                              6300385
# ...

# %%
hs.sum(numeric_only= True)
# Out:
# id               9.899406e+13
# price            1.167293e+10
# bedrooms         7.285400e+04
# bathrooms        4.570625e+04
# sqft_living      4.495287e+07
# sqft_lot         3.265069e+08
# floors           3.229650e+04
# waterfront       1.630000e+02
# view             5.064000e+03
# condition        7.368800e+04
# grade            1.654880e+05
# sqft_above       3.865249e+07
# sqft_basement    6.300385e+06
# yr_built         4.259933e+07
# yr_renovated     1.824186e+06
# zipcode          2.119759e+09
# lat              1.027915e+06
# long            -2.641409e+06
# sqft_living15    4.293536e+07
# sqft_lot15       2.759646e+08
# dtype: float64

# %%
titanic.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#       age  sibsp  parch  ticket      fare    cabin embarked boat body  \
# 0      29      0      0   24160  211.3375       B5        S    2    ?
# 1  0.9167      1      2  113781    151.55  C22 C26        S   11    ?
# 2       2      1      2  113781    151.55  C22 C26        S    ?    ?
# 3      30      1      2  113781    151.55  C22 C26        S    ?  135
# 4      25      1      2  113781    151.55  C22 C26        S    ?    ?
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %%
titanic.sum(numeric_only=True)
# Out:
# pclass      3004
# survived     500
# sibsp        653
# parch        504
# dtype: int64

# %%
state=pd.read_csv('data/nst-est2020.csv')
state
# Out:
#     SUMLEV REGION DIVISION  STATE                  NAME  CENSUS2010POP  \
# 0       10      0        0      0         United States      308745538
# 1       20      1        0      0      Northeast Region       55317240
# 2       20      2        0      0        Midwest Region       66927001
# 3       20      3        0      0          South Region      114555744
# 4       20      4        0      0           West Region       71945553
# 5       40      3        6      1               Alabama        4779736
# 6       40      4        9      2                Alaska         710231
# 7       40      4        8      4               Arizona        6392017
# 8       40      3        7      5              Arkansas        2915918
# 9       40      4        9      6            California       37253956
# 10      40      4        8      8              Colorado        5029196
# 11      40      1        1      9           Connecticut        3574097
# ...

# %%
state.tail(52).head(51).sum(numeric_only=True)
# Out:
# SUMLEV                    2040
# STATE                     1477
# CENSUS2010POP        308745538
# ESTIMATESBASE2010    308758105
# POPESTIMATE2010      309327143
# POPESTIMATE2011      311583481
# POPESTIMATE2012      313877662
# POPESTIMATE2013      316059947
# POPESTIMATE2014      318386329
# POPESTIMATE2015      320738994
# POPESTIMATE2016      323071755
# POPESTIMATE2017      325122128
# POPESTIMATE2018      326838199
# POPESTIMATE2019      328329953
# POPESTIMATE042020    329398742
# POPESTIMATE2020      329484123
# dtype: int64

# %%
titanic.count()
# Out:
# pclass       1309
# survived     1309
# name         1309
# sex          1309
# age          1309
# sibsp        1309
# parch        1309
# ticket       1309
# fare         1309
# cabin        1309
# embarked     1309
# boat         1309
# body         1309
# home.dest    1309
# dtype: int64

# %%
state.count()
# Out:
# SUMLEV               57
# REGION               57
# DIVISION             57
# STATE                57
# NAME                 57
# CENSUS2010POP        57
# ESTIMATESBASE2010    57
# POPESTIMATE2010      57
# POPESTIMATE2011      57
# POPESTIMATE2012      57
# POPESTIMATE2013      57
# POPESTIMATE2014      57
# POPESTIMATE2015      57
# POPESTIMATE2016      57
# POPESTIMATE2017      57
# POPESTIMATE2018      57
# POPESTIMATE2019      57
# POPESTIMATE042020    57
# POPESTIMATE2020      57
# dtype: int64

# %%
netflix.count()
# Out:
# show_id         8807
# type            8807
# title           8807
# director        6173
# cast            7982
# country         7976
# date_added      8797
# release_year    8807
# rating          8803
# duration        8804
# listed_in       8807
# description     8807
# dtype: int64

# %%
state.mode()
# Out:
#     SUMLEV REGION DIVISION  STATE                  NAME  CENSUS2010POP  \
# 0     40.0      3        5    0.0               Alabama         563626
# 1      NaN    NaN      NaN    NaN                Alaska         601723
# 2      NaN    NaN      NaN    NaN               Arizona         625741
# 3      NaN    NaN      NaN    NaN              Arkansas         672591
# 4      NaN    NaN      NaN    NaN            California         710231
# 5      NaN    NaN      NaN    NaN              Colorado         814180
# 6      NaN    NaN      NaN    NaN           Connecticut         897934
# 7      NaN    NaN      NaN    NaN              Delaware         989415
# 8      NaN    NaN      NaN    NaN  District of Columbia        1052567
# 9      NaN    NaN      NaN    NaN               Florida        1316470
# 10     NaN    NaN      NaN    NaN               Georgia        1328361
# 11     NaN    NaN      NaN    NaN                Hawaii        1360301
# ...

# %%
titanic.mode()
# Out:
#    pclass  survived                  name   sex  age  sibsp  parch    ticket  \
# 0     3.0       0.0  Connolly, Miss. Kate  male    ?    0.0    0.0  CA. 2343
# 1     NaN       NaN      Kelly, Mr. James   NaN  NaN    NaN    NaN       NaN
#
#    fare cabin embarked boat body home.dest
# 0  8.05     ?        S    ?    ?         ?
# 1   NaN   NaN      NaN  NaN  NaN       NaN

# %%
titanic.median(numeric_only=True)
# Out:
# pclass      3.0
# survived    0.0
# sibsp       0.0
# parch       0.0
# dtype: float64

# %%
titanic.mode(numeric_only=True)
# Out:
#    pclass  survived  sibsp  parch
# 0       3         0      0      0

# %%
titanic.describe(include=['object'])
# Out:
#                         name   sex   age    ticket  fare cabin embarked  boat  \
# count                   1309  1309  1309      1309  1309  1309     1309  1309
# unique                  1307     2    99       929   282   187        4    28
# top     Connolly, Miss. Kate  male     ?  CA. 2343  8.05     ?        S     ?
# freq                       2   843   263        11    60  1014      914   823
#
#         body home.dest
# count   1309      1309
# unique   122       370
# top        ?         ?
# freq    1188       564

# %% [markdown]
# # Columns and series
# ## How to narrow down individual columns

# %%
import pandas as pd
tit = pd.read_csv('data/titanic.csv')
hos = pd.read_csv('data/kc_house_data.csv')
netflix = pd.read_csv('data/netflix_titles.csv', sep ='|', index_col=0)

# %%
#type(tit['age'])
tit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1309 non-null   object
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1309 non-null   object
#  9   cabin      1309 non-null   object
#  10  embarked   1309 non-null   object
#  11  boat       1309 non-null   object
#  12  body       1309 non-null   object
#  13  home.dest  1309 non-null   object
# dtypes: int64(4), object(10)
# memory usage: 143.3+ KB

# %%
tit.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#       age  sibsp  parch  ticket      fare    cabin embarked boat body  \
# 0      29      0      0   24160  211.3375       B5        S    2    ?
# 1  0.9167      1      2  113781    151.55  C22 C26        S   11    ?
# 2       2      1      2  113781    151.55  C22 C26        S    ?    ?
# 3      30      1      2  113781    151.55  C22 C26        S    ?  135
# 4      25      1      2  113781    151.55  C22 C26        S    ?    ?
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %%
tit.name
# Out:
# 0                           Allen, Miss. Elisabeth Walton
# 1                          Allison, Master. Hudson Trevor
# 2                            Allison, Miss. Helen Loraine
# 3                    Allison, Mr. Hudson Joshua Creighton
# 4         Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5                                     Anderson, Mr. Harry
# 6                       Andrews, Miss. Kornelia Theodosia
# 7                                  Andrews, Mr. Thomas Jr
# 8           Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9                                 Artagaveytia, Mr. Ramon
# 10                                 Astor, Col. John Jacob
# 11      Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 12                          Aubart, Mme. Leontine Pauline
# 13                           Barber, Miss. Ellen 'Nellie'
# 14                   Barkworth, Mr. Algernon Henry Wilson
# 15                                    Baumann, Mr. John D
# ...

# %%
type(tit.name)
# Out:
# pandas.core.series.Series

# %%
tit['name']
# Out:
# 0                           Allen, Miss. Elisabeth Walton
# 1                          Allison, Master. Hudson Trevor
# 2                            Allison, Miss. Helen Loraine
# 3                    Allison, Mr. Hudson Joshua Creighton
# 4         Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5                                     Anderson, Mr. Harry
# 6                       Andrews, Miss. Kornelia Theodosia
# 7                                  Andrews, Mr. Thomas Jr
# 8           Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9                                 Artagaveytia, Mr. Ramon
# 10                                 Astor, Col. John Jacob
# 11      Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 12                          Aubart, Mme. Leontine Pauline
# 13                           Barber, Miss. Ellen 'Nellie'
# 14                   Barkworth, Mr. Algernon Henry Wilson
# 15                                    Baumann, Mr. John D
# ...

# %%
tit['home.dest']
# Out:
# 0                          St Louis, MO
# 1       Montreal, PQ / Chesterville, ON
# 2       Montreal, PQ / Chesterville, ON
# 3       Montreal, PQ / Chesterville, ON
# 4       Montreal, PQ / Chesterville, ON
# 5                          New York, NY
# 6                            Hudson, NY
# 7                           Belfast, NI
# 8                   Bayside, Queens, NY
# 9                   Montevideo, Uruguay
# 10                         New York, NY
# 11                         New York, NY
# 12                        Paris, France
# 13                                    ?
# 14                        Hessle, Yorks
# 15                         New York, NY
# 16                         Montreal, PQ
# 17                         Montreal, PQ
# 18                                    ?
# 19                         Winnipeg, MN
# 20                         New York, NY
# 21                         New York, NY
# 22                         New York, NY
# ...

# %%
tit['age'].head(10)
# Out:
# 0        29
# 1    0.9167
# 2         2
# 3        30
# 4        25
# 5        48
# 6        63
# 7        39
# 8        53
# 9        71
# Name: age, dtype: object

# %%
tit['age'].tail(10)
# Out:
# 1299      27
# 1300      15
# 1301    45.5
# 1302       ?
# 1303       ?
# 1304    14.5
# 1305       ?
# 1306    26.5
# 1307      27
# 1308      29
# Name: age, dtype: object

# %%
tit.describe
# Out:
# <bound method NDFrame.describe of       pclass  survived                                               name  \
# 0          1         1                      Allen, Miss. Elisabeth Walton
# 1          1         1                     Allison, Master. Hudson Trevor
# 2          1         0                       Allison, Miss. Helen Loraine
# 3          1         0               Allison, Mr. Hudson Joshua Creighton
# 4          1         0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5          1         1                                Anderson, Mr. Harry
# 6          1         1                  Andrews, Miss. Kornelia Theodosia
# 7          1         0                             Andrews, Mr. Thomas Jr
# 8          1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9          1         0                            Artagaveytia, Mr. Ramon
# 10         1         0                             Astor, Col. John Jacob
# ...

# %%
netflix['title'].tail(10)
# Out:
# 8797             Zak Storm
# 8798              Zed Plus
# 8799                 Zenda
# 8800    Zindagi Gulzar Hai
# 8801               Zinzana
# 8802                Zodiac
# 8803           Zombie Dumb
# 8804            Zombieland
# 8805                  Zoom
# 8806                Zubaan
# Name: title, dtype: object

# %%
tit.describe(include=['object','int64'])
# Out:
#              pclass     survived                  name   sex   age  \
# count   1309.000000  1309.000000                  1309  1309  1309
# unique          NaN          NaN                  1307     2    99
# top             NaN          NaN  Connolly, Miss. Kate  male     ?
# freq            NaN          NaN                     2   843   263
# mean       2.294882     0.381971                   NaN   NaN   NaN
# std        0.837836     0.486055                   NaN   NaN   NaN
# min        1.000000     0.000000                   NaN   NaN   NaN
# 25%        2.000000     0.000000                   NaN   NaN   NaN
# 50%        3.000000     0.000000                   NaN   NaN   NaN
# 75%        3.000000     1.000000                   NaN   NaN   NaN
# max        3.000000     1.000000                   NaN   NaN   NaN
#
#               sibsp        parch    ticket  fare cabin embarked  boat  body  \
# count   1309.000000  1309.000000      1309  1309  1309     1309  1309  1309
# ...

# %%
tit['sex'].describe()
# Out:
# count     1309
# unique       2
# top       male
# freq       843
# Name: sex, dtype: object

# %%
netflix['rating'].unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR', nan,
#        'TV-Y7-FV', 'UR'], dtype=object)

# %%
netflix['rating'].nunique(dropna=True)
# Out:
# 17

# %%
hos['zipcode'].unique()
# Out:
# array([98178, 98125, 98028, 98136, 98074, 98053, 98003, 98198, 98146,
#        98038, 98007, 98115, 98107, 98126, 98019, 98103, 98002, 98133,
#        98040, 98092, 98030, 98119, 98112, 98052, 98027, 98117, 98058,
#        98001, 98056, 98166, 98023, 98070, 98148, 98105, 98042, 98008,
#        98059, 98122, 98144, 98004, 98005, 98034, 98075, 98116, 98010,
#        98118, 98199, 98032, 98045, 98102, 98077, 98108, 98168, 98177,
#        98065, 98029, 98006, 98109, 98022, 98033, 98155, 98024, 98011,
#        98031, 98106, 98072, 98188, 98014, 98055, 98039])

# %%
hos['zipcode'].nunique(dropna =True)
# Out:
# 70

# %%
hos['price'].nlargest()
# Out:
# 7252    7700000.0
# 3914    7062500.0
# 9254    6885000.0
# 4411    5570000.0
# 1448    5350000.0
# Name: price, dtype: float64

# %%
hos['price'].nsmallest(keep ='all')
# Out:
# 1149     75000.0
# 15293    78000.0
# 465      80000.0
# 16198    81000.0
# 8274     82000.0
# Name: price, dtype: float64

# %%
tit['pclass'].nlargest(keep ='all')

#this is for series
# Out:
# 600     3
# 601     3
# 602     3
# 603     3
# 604     3
# 605     3
# 606     3
# 607     3
# 608     3
# 609     3
# 610     3
# 611     3
# 612     3
# 613     3
# 614     3
# 615     3
# 616     3
# 617     3
# 618     3
# 619     3
# 620     3
# 621     3
# 622     3
# 623     3
# 624     3
#        ..
# 1284    3
# 1285    3
# 1286    3
# 1287    3
# 1288    3
# 1289    3
# 1290    3
# 1291    3
# 1292    3
# 1293    3
# 1294    3
# 1295    3
# 1296    3
# 1297    3
# 1298    3
# 1299    3
# 1300    3
# 1301    3
# 1302    3
# 1303    3
# 1304    3
# 1305    3
# 1306    3
# 1307    3
# 1308    3
# Name: pclass, Length: 709, dtype: int64

# %%
hos.nlargest(5,['price'])
#this is for dataframes
# Out:
#               id             date      price  bedrooms  bathrooms  \
# 7252  6762700020  20141013T000000  7700000.0         6       8.00
# 3914  9808700762  20140611T000000  7062500.0         5       4.50
# 9254  9208900037  20140919T000000  6885000.0         6       7.75
# 4411  2470100110  20140804T000000  5570000.0         5       5.75
# 1448  8907500070  20150413T000000  5350000.0         5       5.00
#
#       sqft_living  sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 7252        12050     27600     2.5           0     3  ...     13        8570
# 3914        10040     37325     2.0           1     2  ...     11        7680
# 9254         9890     31374     2.0           0     4  ...     13        8860
# 4411         9200     35069     2.0           0     0  ...     13        6200
# 1448         8000     23985     2.0           0     4  ...     12        6720
#
#       sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
hos['id'].nsmallest(5, keep='all')
# Out:
# 2496    1000102
# 2497    1000102
# 6735    1200019
# 8411    1200021
# 8809    2800031
# Name: id, dtype: int64

# %%
hos.nsmallest(10,['price','bedrooms','grade'])
# Out:
#                id             date    price  bedrooms  bathrooms  sqft_living  \
# 1149   3421079032  20150217T000000  75000.0         1       0.00          670
# 15293    40000362  20140506T000000  78000.0         2       1.00          780
# 465    8658300340  20140523T000000  80000.0         1       0.75          430
# 16198  3028200080  20150324T000000  81000.0         2       1.00          730
# 8274   3883800011  20141105T000000  82000.0         3       1.00          860
# 2141   1623049041  20140508T000000  82500.0         2       1.00          520
# 18468  7999600180  20140529T000000  83000.0         2       1.00          900
# 3767   1523049188  20150430T000000  84000.0         2       1.00          700
# 16714  1322049150  20150305T000000  85000.0         2       1.00          910
# 10253  2422049104  20140915T000000  85000.0         2       1.00          830
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %% [markdown]
# # how to select multiple columns
# ## To do that we use '[ [ ] ]'

# %%
netflix[['title','rating',]].head()
# Out:
#                    title rating
# 0   Dick Johnson Is Dead  PG-13
# 1          Blood & Water  TV-MA
# 2              Ganglands  TV-MA
# 3  Jailbirds New Orleans  TV-MA
# 4           Kota Factory  TV-MA

# %%
hos[['price','bathrooms','bedrooms']].describe()
# Out:
#               price     bathrooms      bedrooms
# count  2.161300e+04  21613.000000  21613.000000
# mean   5.400881e+05      2.114757      3.370842
# std    3.671272e+05      0.770163      0.930062
# min    7.500000e+04      0.000000      0.000000
# 25%    3.219500e+05      1.750000      3.000000
# 50%    4.500000e+05      2.250000      3.000000
# 75%    6.450000e+05      2.500000      4.000000
# max    7.700000e+06      8.000000     33.000000

# %%
hos.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
cols=['price','bathrooms','bedrooms']
hos[cols]
# Out:
#            price  bathrooms  bedrooms
# 0       221900.0       1.00         3
# 1       538000.0       2.25         3
# 2       180000.0       1.00         2
# 3       604000.0       3.00         4
# 4       510000.0       2.00         3
# 5      1225000.0       4.50         4
# 6       257500.0       2.25         3
# 7       291850.0       1.50         3
# 8       229500.0       1.00         3
# 9       323000.0       2.50         3
# 10      662500.0       2.50         3
# 11      468000.0       1.00         2
# 12      310000.0       1.00         3
# 13      400000.0       1.75         3
# 14      530000.0       2.00         5
# 15      650000.0       3.00         4
# 16      395000.0       2.00         3
# 17      485000.0       1.00         4
# 18      189000.0       1.00         2
# 19      230000.0       1.00         3
# 20      385000.0       1.75         4
# 21     2000000.0       2.75         3
# 22      285000.0       2.50         5
# 23      252700.0       1.50         2
# ...

# %%
type(cols)
# Out:
# list

# %% [markdown]
# # counting the number of times something appeared
# ## we use a method called '.value_counts()'

# %%
hos['bedrooms'].value_counts()
#first of all we print out the series
# Out:
# 3     9824
# 4     6882
# 2     2760
# 5     1601
# 6      272
# 1      199
# 7       38
# 0       13
# 8       13
# 9        6
# 10       3
# 11       1
# 33       1
# Name: bedrooms, dtype: int64

# %%
hos.bedrooms.shape
# Out:
# (21613,)

# %%
tit['sex'].value_counts()
# Out:
# male      843
# female    466
# Name: sex, dtype: int64

# %%
netflix.director.value_counts(ascending=True)
# Out:
# Kirsten Johnson                   1
# Evgeny Afineevsky                 1
# Kristina Goolsby, Ashley York     1
# Phil Joanou                       1
# Anthony Pierce                    1
# Jennifer Phang                    1
# Jill Bauer, Ronna Gradus          1
# Mike Fleiss                       1
# Aziz Ansari                       1
# David Sampliner                   1
# Katy Chevigny, Ross Kauffman      1
# Wyatt Cenac                       1
# Luis Lopez, Clay Tweel            1
# Robert Nixon, Fisher Stevens      1
# Greg Whiteley                     1
# Jehane Noujaim                    1
# Jason Moore                       1
# Josh Greenbaum                    1
# Will Lovelace, Dylan Southern     1
# Constance Marks                   1
# Larry Elikann                     1
# Robert Markowitz                  1
# Eric Laneuville                   1
# Joel Oliansky                     1
# Roy Campanella II                 1
#                                  ..
# ...

# %%
tit.index
# Out:
# RangeIndex(start=0, stop=1309, step=1)

# %%
tit
# Out:
#       pclass  survived                                               name  \
# 0          1         1                      Allen, Miss. Elisabeth Walton
# 1          1         1                     Allison, Master. Hudson Trevor
# 2          1         0                       Allison, Miss. Helen Loraine
# 3          1         0               Allison, Mr. Hudson Joshua Creighton
# 4          1         0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5          1         1                                Anderson, Mr. Harry
# 6          1         1                  Andrews, Miss. Kornelia Theodosia
# 7          1         0                             Andrews, Mr. Thomas Jr
# 8          1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9          1         0                            Artagaveytia, Mr. Ramon
# 10         1         0                             Astor, Col. John Jacob
# 11         1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# ...

# %%
netflix.director.value_counts().head(10)
# Out:
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Suhas Kadav               16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Youssef Chahine           12
# Jay Chapman               12
# Steven Spielberg          11
# Name: director, dtype: int64

# %%
hos['floors'].value_counts()
# Out:
# 1.0    10680
# 2.0     8241
# 1.5     1910
# 3.0      613
# 2.5      161
# 3.5        8
# Name: floors, dtype: int64

# %%
hos[['bedrooms','bathrooms']].value_counts()
# Out:
# bedrooms  bathrooms
# 4         2.50         2502
# 3         2.50         2357
#           1.75         1870
#           1.00         1780
# 2         1.00         1558
# 3         2.25         1082
#           2.00         1048
#           1.50          829
# 4         1.75          719
#           2.25          709
#           2.75          639
#           2.00          525
#           3.50          395
#           3.00          326
#           1.00          325
# 2         1.75          304
#           1.50          294
# 5         2.50          287
# 3         2.75          275
# 4         3.25          254
#           1.50          254
# 2         2.00          216
# 5         2.75          214
# 3         3.00          197
# 2         2.50          197
#                        ...
# 9         7.50            1
# 8         2.50            1
#           3.75            1
# 9         4.00            1
# 8         5.00            1
# 4         5.75            1
# ...

# %% [markdown]
# # How to plot a graph
# ### we use the '.plot' method
# # we can plot from series and dataframes

# %%
hos['bedrooms'].plot()
# Out:
# <AxesSubplot:>

# %%
hos['bedrooms'].value_counts().plot()
#
# Out:
# <AxesSubplot:>

# %%
hos['bedrooms'].value_counts().plot(kind='bar')
# you can pass the preferred kind to the plot being it bar,hist
# Out:
# <AxesSubplot:>

# %%
hos['bedrooms'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='bedrooms'>

# %%
tit['survived'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='survived'>

# %% [markdown]
# # Plotting is Dataframes

# %%
hos.plot()
# Out:
# <AxesSubplot:>

# %%
hos[['price','bedrooms']].head()
# Out:
#       price  bedrooms
# 0  221900.0         3
# 1  538000.0         3
# 2  180000.0         2
# 3  604000.0         4
# 4  510000.0         3

# %%
hos[['price','bedrooms']].plot(subplots=True)
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>], dtype=object)

# %% [markdown]
# # this is how we postion x and y values in a plot

# %%
pt=hos[['bathrooms','bedrooms']]
pt.plot(kind='scatter',x='bedrooms',y='bathrooms')
# Out:
# <AxesSubplot:xlabel='bedrooms', ylabel='bathrooms'>

# %%
netflix.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
netflix['rating'].value_counts().head(10).plot(kind='barh')
# Adding h to the bar marks the bar horizontal
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Index and Sorting

# %%
#this is when i wanna change the name for the column names 

btc= pd.read_csv('data/coin_Bitcoin.csv')
btc
# Out:
#        SNo     Name Symbol                 Date          High           Low  \
# 0        1  Bitcoin    BTC  2013-04-29 23:59:59    147.488007    134.000000
# 1        2  Bitcoin    BTC  2013-04-30 23:59:59    146.929993    134.050003
# 2        3  Bitcoin    BTC  2013-05-01 23:59:59    139.889999    107.720001
# 3        4  Bitcoin    BTC  2013-05-02 23:59:59    125.599998     92.281898
# 4        5  Bitcoin    BTC  2013-05-03 23:59:59    108.127998     79.099998
# 5        6  Bitcoin    BTC  2013-05-04 23:59:59    115.000000     92.500000
# 6        7  Bitcoin    BTC  2013-05-05 23:59:59    118.800003    107.142998
# 7        8  Bitcoin    BTC  2013-05-06 23:59:59    124.663002    106.639999
# 8        9  Bitcoin    BTC  2013-05-07 23:59:59    113.444000     97.699997
# 9       10  Bitcoin    BTC  2013-05-08 23:59:59    115.779999    109.599998
# 10      11  Bitcoin    BTC  2013-05-09 23:59:59    113.459999    109.260002
# ...

# %%
# this is done when you wanna change the index of a dataframe 
btc.set_index('Symbol', inplace=True)
btc
# Out:
#          SNo     Name                 Date          High           Low  \
# Symbol
# BTC        1  Bitcoin  2013-04-29 23:59:59    147.488007    134.000000
# BTC        2  Bitcoin  2013-04-30 23:59:59    146.929993    134.050003
# BTC        3  Bitcoin  2013-05-01 23:59:59    139.889999    107.720001
# BTC        4  Bitcoin  2013-05-02 23:59:59    125.599998     92.281898
# BTC        5  Bitcoin  2013-05-03 23:59:59    108.127998     79.099998
# BTC        6  Bitcoin  2013-05-04 23:59:59    115.000000     92.500000
# BTC        7  Bitcoin  2013-05-05 23:59:59    118.800003    107.142998
# BTC        8  Bitcoin  2013-05-06 23:59:59    124.663002    106.639999
# BTC        9  Bitcoin  2013-05-07 23:59:59    113.444000     97.699997
# BTC       10  Bitcoin  2013-05-08 23:59:59    115.779999    109.599998
# BTC       11  Bitcoin  2013-05-09 23:59:59    113.459999    109.260002
# BTC       12  Bitcoin  2013-05-10 23:59:59    122.000000    111.551003
# ...

# %%
btc.index
# Out:
# Index(['BTC', 'BTC', 'BTC', 'BTC', 'BTC', 'BTC', 'BTC', 'BTC', 'BTC', 'BTC',
#        ...
#        'BTC', 'BTC', 'BTC', 'BTC', 'BTC', 'BTC', 'BTC', 'BTC', 'BTC', 'BTC'],
#       dtype='object', name='Symbol', length=2991)

# %%
btc['High'].plot()
# Out:
# <AxesSubplot:xlabel='Symbol'>

# %% [markdown]
# # HOW TO SELECT A COLUMN AS AN INDEX OF A DATASET OR A DATAFRAME
#
# ## USE 'DATAFRAME.SET_INDEX(THE COLUMN NAME)
# ### USE INPLACE TO SET TO DEFAULT

# %%
country=pd.read_csv('data/world-happiness-report-2021.csv')
country.set_index('Country name', inplace=True)
country
# Out:
#                                     Regional indicator  Ladder score  \
# Country name
# Finland                                 Western Europe         7.842
# Denmark                                 Western Europe         7.620
# Switzerland                             Western Europe         7.571
# Iceland                                 Western Europe         7.554
# Netherlands                             Western Europe         7.464
# Norway                                  Western Europe         7.392
# Sweden                                  Western Europe         7.363
# Luxembourg                              Western Europe         7.324
# New Zealand                      North America and ANZ         7.277
# Austria                                 Western Europe         7.268
# Australia                        North America and ANZ         7.183
# Israel                    Middle East and North Africa         7.157
# ...

# %%
plt=country[['upperwhisker','Regional indicator']].head(5)
plt.plot(kind='scatter',x= 'upperwhisker', y= 'Regional indicator')
# Out:
# <AxesSubplot:xlabel='upperwhisker', ylabel='Regional indicator'>

# %%
country['Healthy life expectancy'].head().plot()
# Out:
# <AxesSubplot:xlabel='Country name'>

# %% [markdown]
# # Sorting

# %%
country.sort_values('Healthy life expectancy')
# default is by the ascending order 
#this is sorting for dataframe
# Out:
#                                      Regional indicator  Ladder score  \
# Country name
# Chad                                 Sub-Saharan Africa         4.355
# Lesotho                              Sub-Saharan Africa         3.512
# Nigeria                              Sub-Saharan Africa         4.759
# Ivory Coast                          Sub-Saharan Africa         5.306
# Swaziland                            Sub-Saharan Africa         4.308
# Sierra Leone                         Sub-Saharan Africa         3.849
# Mali                                 Sub-Saharan Africa         4.723
# Afghanistan                                  South Asia         2.523
# Burundi                              Sub-Saharan Africa         3.775
# Cameroon                             Sub-Saharan Africa         5.142
# Niger                                Sub-Saharan Africa         5.074
# Burkina Faso                         Sub-Saharan Africa         4.834
# ...

# %%
country.sort_values('Ladder score', inplace=True)
country
# Out:
#                                     Regional indicator  Ladder score  \
# Country name
# Afghanistan                                 South Asia         2.523
# Zimbabwe                            Sub-Saharan Africa         3.145
# Rwanda                              Sub-Saharan Africa         3.415
# Botswana                            Sub-Saharan Africa         3.467
# Lesotho                             Sub-Saharan Africa         3.512
# Malawi                              Sub-Saharan Africa         3.600
# Haiti                      Latin America and Caribbean         3.615
# Tanzania                            Sub-Saharan Africa         3.623
# Yemen                     Middle East and North Africa         3.658
# Burundi                             Sub-Saharan Africa         3.775
# India                                       South Asia         3.819
# Sierra Leone                        Sub-Saharan Africa         3.849
# ...

# %%
country['Ladder score'].sort_index()
#This is sorting for series
# Out:
# Country name
# Afghanistan                 2.523
# Albania                     5.117
# Algeria                     4.887
# Argentina                   5.929
# Armenia                     5.283
# Australia                   7.183
# Austria                     7.268
# Azerbaijan                  5.171
# Bahrain                     6.647
# Bangladesh                  5.025
# Belarus                     5.534
# Belgium                     6.834
# Benin                       5.045
# Bolivia                     5.716
# Bosnia and Herzegovina      5.813
# Botswana                    3.467
# Brazil                      6.330
# Bulgaria                    5.266
# Burkina Faso                4.834
# Burundi                     3.775
# Cambodia                    4.830
# Cameroon                    5.142
# Canada                      7.103
# Chad                        4.355
# Chile                       6.172
#                             ...
# Spain                       6.491
# ...

# %%
titanic.set_index('name',inplace=True)
#so this will change your first field name

# %%
titanic
# Out:
#                                                    pclass  survived     sex  \
# name
# Allen, Miss. Elisabeth Walton                           1         1  female
# Allison, Master. Hudson Trevor                          1         1    male
# Allison, Miss. Helen Loraine                            1         0  female
# Allison, Mr. Hudson Joshua Creighton                    1         0    male
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)         1         0  female
# Anderson, Mr. Harry                                     1         1    male
# Andrews, Miss. Kornelia Theodosia                       1         1  female
# Andrews, Mr. Thomas Jr                                  1         0    male
# Appleton, Mrs. Edward Dale (Charlotte Lamson)           1         1  female
# Artagaveytia, Mr. Ramon                                 1         0    male
# Astor, Col. John Jacob                                  1         0    male
# ...

# %%
titanic['age'].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
band=pd.read_csv('data/bands.csv', index_col=0)
band.head()
# Out:
#                   name        country    status  formed_in        genre  \
# id
# 1           ('M') Inc.  United States   Unknown     2009.0  Death Metal
# 2                (sic)  United States  Split-up     1993.0  Death Metal
# 3            .F.O.A.D.         France    Active     2009.0  Death Metal
# 4             100 Suns  United States    Active     2004.0  Death Metal
# 5   12 Days of Anarchy  United States  Split-up     1998.0  Death Metal
#
#              theme        active
# id
# 1              NaN        2009-?
# 2              NaN     1993-1996
# 3   Life and Death  2009-present
# 4              NaN  2004-present
# 5          Anarchy     1998-2002

# %%
band.sort_values(['formed_in','country'], ascending=False).head()
# Out:
#                    name        country        status  formed_in  \
# id
# 494             Aphotic  United States        Active     2016.0
# 9455   Wise as Serpents  United States        Active     2016.0
# 10118           Arnheim  United States        Active     2016.0
# 12630         Goatflesh  United States  Changed name     2016.0
# 14833       Pyrolatrous  United States        Active     2016.0
#
#                                genre                          theme  \
# id
# 494                      Death Metal                            NaN
# 9455                     Death Metal  Christianity| Social Problems
# 10118            Melodic Death Metal                            NaN
# 12630          Blackened Death Metal                            NaN
# 14833  Blackened Melodic Death Metal                            NaN
#
#                                                 active
# id
# 494    2011-2016 (as Betray the Prophet)| 2016-present
# ...

# %% [markdown]
# # sorting text
# ## we use 'key=lambda col:col.str.lower()'

# %%
country.head()
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Afghanistan           South Asia         2.523
# Zimbabwe      Sub-Saharan Africa         3.145
# Rwanda        Sub-Saharan Africa         3.415
# Botswana      Sub-Saharan Africa         3.467
# Lesotho       Sub-Saharan Africa         3.512
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Afghanistan                            0.038         2.596         2.449
# Zimbabwe                               0.058         3.259         3.030
# Rwanda                                 0.068         3.548         3.282
# Botswana                               0.074         3.611         3.322
# Lesotho                                0.120         3.748         3.276
#
#               Logged GDP per capita  Social support  Healthy life expectancy  \
# Country name
# Afghanistan                   7.695           0.463                   52.493
# ...

# %%
country.sort_values('Country name',key=lambda col:col.str.lower() ).head()
# Out:
#                               Regional indicator  Ladder score  \
# Country name
# Afghanistan                           South Asia         2.523
# Albania               Central and Eastern Europe         5.117
# Algeria             Middle East and North Africa         4.887
# Argentina            Latin America and Caribbean         5.929
# Armenia       Commonwealth of Independent States         5.283
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Afghanistan                            0.038         2.596         2.449
# Albania                                0.059         5.234         5.001
# Algeria                                0.053         4.991         4.783
# Argentina                              0.056         6.040         5.819
# Armenia                                0.058         5.397         5.168
#
#               Logged GDP per capita  Social support  Healthy life expectancy  \
# Country name
# ...

# %% [markdown]
# # Sorting single index

# %%
titanic
# Out:
#                                                    pclass  survived     sex  \
# name
# Allen, Miss. Elisabeth Walton                           1         1  female
# Allison, Master. Hudson Trevor                          1         1    male
# Allison, Miss. Helen Loraine                            1         0  female
# Allison, Mr. Hudson Joshua Creighton                    1         0    male
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)         1         0  female
# Anderson, Mr. Harry                                     1         1    male
# Andrews, Miss. Kornelia Theodosia                       1         1  female
# Andrews, Mr. Thomas Jr                                  1         0    male
# Appleton, Mrs. Edward Dale (Charlotte Lamson)           1         1  female
# Artagaveytia, Mr. Ramon                                 1         0    male
# Astor, Col. John Jacob                                  1         0    male
# ...

# %%
tit.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#       age  sibsp  parch  ticket      fare    cabin embarked boat body  \
# 0      29      0      0   24160  211.3375       B5        S    2    ?
# 1  0.9167      1      2  113781    151.55  C22 C26        S   11    ?
# 2       2      1      2  113781    151.55  C22 C26        S    ?    ?
# 3      30      1      2  113781    151.55  C22 C26        S    ?  135
# 4      25      1      2  113781    151.55  C22 C26        S    ?    ?
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %%
tit.sort_index(ascending=False)
# Out:
#       pclass  survived                                               name  \
# 1308       3         0                                 Zimmerman, Mr. Leo
# 1307       3         0                                Zakarian, Mr. Ortin
# 1306       3         0                          Zakarian, Mr. Mapriededer
# 1305       3         0                              Zabour, Miss. Thamine
# 1304       3         0                               Zabour, Miss. Hileni
# 1303       3         0                              Yousseff, Mr. Gerious
# 1302       3         0                                  Yousif, Mr. Wazli
# 1301       3         0                               Youseff, Mr. Gerious
# 1300       3         1            Yasbeck, Mrs. Antoni (Selini Alexander)
# 1299       3         0                                Yasbeck, Mr. Antoni
# 1298       3         0                          Wittevrongel, Mr. Camille
# 1297       3         0                             Wiseman, Mr. Phillippe
# ...

# %%
tit['pclass'].value_counts()
# Out:
# 3    709
# 1    323
# 2    277
# Name: pclass, dtype: int64

# %%
tit['pclass'].value_counts().sort_values().plot(kind='bar')
#this is how we can sort values>>> the vertical
# Out:
# <AxesSubplot:>

# %%
tit['pclass'].value_counts().sort_index(ascending=False).plot(kind='bar')
#this is how we sort on the horizontal line
# Out:
# <AxesSubplot:>

# %%
houses.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
houses['bedrooms'].value_counts().sort_values().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # loc>>>> the method that helps select a row

# %%
country.head()
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Afghanistan           South Asia         2.523
# Zimbabwe      Sub-Saharan Africa         3.145
# Rwanda        Sub-Saharan Africa         3.415
# Botswana      Sub-Saharan Africa         3.467
# Lesotho       Sub-Saharan Africa         3.512
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Afghanistan                            0.038         2.596         2.449
# Zimbabwe                               0.058         3.259         3.030
# Rwanda                                 0.068         3.548         3.282
# Botswana                               0.074         3.611         3.322
# Lesotho                                0.120         3.748         3.276
#
#               Logged GDP per capita  Social support  Healthy life expectancy  \
# Country name
# Afghanistan                   7.695           0.463                   52.493
# ...

# %%
country.loc['Rwanda']
# Out:
# Regional indicator                            Sub-Saharan Africa
# Ladder score                                               3.415
# Standard error of ladder score                             0.068
# upperwhisker                                               3.548
# lowerwhisker                                               3.282
# Logged GDP per capita                                      7.676
# Social support                                             0.552
# Healthy life expectancy                                     61.4
# Freedom to make life choices                               0.897
# Generosity                                                 0.061
# Perceptions of corruption                                  0.167
# Ladder score in Dystopia                                    2.43
# Explained by: Log GDP per capita                           0.364
# Explained by: Social support                               0.202
# ...

# %%
#how to convert series to a dataframe by columns
stod =country[['Regional indicator']]
stod.head()
# Out:
#               Regional indicator
# Country name
# Afghanistan           South Asia
# Zimbabwe      Sub-Saharan Africa
# Rwanda        Sub-Saharan Africa
# Botswana      Sub-Saharan Africa
# Lesotho       Sub-Saharan Africa

# %%
#how to convert series of a dataframe by rows
country.loc[['Rwanda']]
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Rwanda        Sub-Saharan Africa         3.415
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Rwanda                                 0.068         3.548         3.282
#
#               Logged GDP per capita  Social support  Healthy life expectancy  \
# Country name
# Rwanda                        7.676           0.552                     61.4
#
#               Freedom to make life choices  Generosity  \
# Country name
# Rwanda                               0.897       0.061
#
#               Perceptions of corruption  Ladder score in Dystopia  \
# Country name
# Rwanda                            0.167                      2.43
#
#               Explained by: Log GDP per capita  Explained by: Social support  \
# Country name
# Rwanda                                   0.364                         0.202
#
#               Explained by: Healthy life expectancy  \
# ...

# %%
#how to convert series of a dataframe by rows>>>>>multiple rows
country.loc[['Rwanda','Canada','United States']]
# Out:
#                   Regional indicator  Ladder score  \
# Country name
# Rwanda            Sub-Saharan Africa         3.415
# Canada         North America and ANZ         7.103
# United States  North America and ANZ         6.951
#
#                Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Rwanda                                  0.068         3.548         3.282
# Canada                                  0.042         7.185         7.021
# United States                           0.049         7.047         6.856
#
#                Logged GDP per capita  Social support  Healthy life expectancy  \
# Country name
# Rwanda                         7.676           0.552                     61.4
# Canada                        10.776           0.926                     73.8
# United States                 11.023           0.920                     68.2
#
#                Freedom to make life choices  Generosity  \
# Country name
# ...

# %% [markdown]
# # loc using numbers and slice functioin

# %%
tit.loc[[6,5]]
# Out:
#    pclass  survived                               name     sex age  sibsp  \
# 6       1         1  Andrews, Miss. Kornelia Theodosia  female  63      1
# 5       1         1                Anderson, Mr. Harry    male  48      0
#
#    parch ticket     fare cabin embarked boat body     home.dest
# 6      0  13502  77.9583    D7        S   10    ?    Hudson, NY
# 5      0  19952    26.55   E12        S    3    ?  New York, NY

# %%
# slicing is selecting rows together with ':'
# where both numbers selected is inclusive
tit.loc[4:8]
# Out:
#    pclass  survived                                             name     sex  \
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# 5       1         1                              Anderson, Mr. Harry    male
# 6       1         1                Andrews, Miss. Kornelia Theodosia  female
# 7       1         0                           Andrews, Mr. Thomas Jr    male
# 8       1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)  female
#
#   age  sibsp  parch  ticket     fare    cabin embarked boat body  \
# 4  25      1      2  113781   151.55  C22 C26        S    ?    ?
# 5  48      0      0   19952    26.55      E12        S    3    ?
# 6  63      1      0   13502  77.9583       D7        S   10    ?
# 7  39      0      0  112050        0      A36        S    ?    ?
# 8  53      2      0   11769  51.4792     C101        S    D    ?
#
#                          home.dest
# 4  Montreal, PQ / Chesterville, ON
# 5                     New York, NY
# ...

# %%
# we can do the step at the very end 
# lets say if you want a step by 2 you do >>>>:2 at the end
tit.loc[4:8:2]
# Out:
#    pclass  survived                                             name     sex  \
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# 6       1         1                Andrews, Miss. Kornelia Theodosia  female
# 8       1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)  female
#
#   age  sibsp  parch  ticket     fare    cabin embarked boat body  \
# 4  25      1      2  113781   151.55  C22 C26        S    ?    ?
# 6  63      1      0   13502  77.9583       D7        S   10    ?
# 8  53      2      0   11769  51.4792     C101        S    D    ?
#
#                          home.dest
# 4  Montreal, PQ / Chesterville, ON
# 6                       Hudson, NY
# 8              Bayside, Queens, NY

# %% [markdown]
# # iloc a method for numeric position indexing

# %%
country.head()
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Afghanistan           South Asia         2.523
# Zimbabwe      Sub-Saharan Africa         3.145
# Rwanda        Sub-Saharan Africa         3.415
# Botswana      Sub-Saharan Africa         3.467
# Lesotho       Sub-Saharan Africa         3.512
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Afghanistan                            0.038         2.596         2.449
# Zimbabwe                               0.058         3.259         3.030
# Rwanda                                 0.068         3.548         3.282
# Botswana                               0.074         3.611         3.322
# Lesotho                                0.120         3.748         3.276
#
#               Logged GDP per capita  Social support  Healthy life expectancy  \
# Country name
# Afghanistan                   7.695           0.463                   52.493
# ...

# %%
# It shows a row basing on the position of the inputed interger using iloc
#so basically iloc is for positioning like the position of the element you wanna sort being the positioin ex. 1st = 1
country.iloc[[3,100,12]]
# Out:
#                        Regional indicator  Ladder score  \
# Country name
# Botswana               Sub-Saharan Africa         3.467
# El Salvador   Latin America and Caribbean         6.061
# Zambia                 Sub-Saharan Africa         4.073
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Botswana                               0.074         3.611         3.322
# El Salvador                            0.065         6.188         5.933
# Zambia                                 0.069         4.209         3.938
#
#               Logged GDP per capita  Social support  Healthy life expectancy  \
# Country name
# Botswana                      9.782           0.784                   59.269
# El Salvador                   9.054           0.762                   66.402
# Zambia                        8.145           0.708                   55.809
#
#               Freedom to make life choices  Generosity  \
# Country name
# ...

# %%
country.head(10)
# Out:
#                         Regional indicator  Ladder score  \
# Country name
# Afghanistan                     South Asia         2.523
# Zimbabwe                Sub-Saharan Africa         3.145
# Rwanda                  Sub-Saharan Africa         3.415
# Botswana                Sub-Saharan Africa         3.467
# Lesotho                 Sub-Saharan Africa         3.512
# Malawi                  Sub-Saharan Africa         3.600
# Haiti          Latin America and Caribbean         3.615
# Tanzania                Sub-Saharan Africa         3.623
# Yemen         Middle East and North Africa         3.658
# Burundi                 Sub-Saharan Africa         3.775
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Afghanistan                            0.038         2.596         2.449
# Zimbabwe                               0.058         3.259         3.030
# Rwanda                                 0.068         3.548         3.282
# ...

# %%
# how to use steps in iloc
country.iloc[0:10:2]
# Out:
#                         Regional indicator  Ladder score  \
# Country name
# Afghanistan                     South Asia         2.523
# Rwanda                  Sub-Saharan Africa         3.415
# Lesotho                 Sub-Saharan Africa         3.512
# Haiti          Latin America and Caribbean         3.615
# Yemen         Middle East and North Africa         3.658
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Afghanistan                            0.038         2.596         2.449
# Rwanda                                 0.068         3.548         3.282
# Lesotho                                0.120         3.748         3.276
# Haiti                                  0.173         3.953         3.276
# Yemen                                  0.070         3.794         3.521
#
#               Logged GDP per capita  Social support  Healthy life expectancy  \
# Country name
# ...

# %% [markdown]
# # LOC AND ILOC with series

# %%
# so this is about selecting the rows and columns you want using loc
houses.loc[1:4, ['price','bedrooms']]
# Out:
#       price  bedrooms
# 1  538000.0         3
# 2  180000.0         2
# 3  604000.0         4
# 4  510000.0         3

# %%
# so this is about selecting rows and columns using steps 
tit.loc[0:10:2, ['name','sex','age']]
# Out:
#                                                name     sex age
# 0                     Allen, Miss. Elisabeth Walton  female  29
# 2                      Allison, Miss. Helen Loraine  female   2
# 4   Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25
# 6                 Andrews, Miss. Kornelia Theodosia  female  63
# 8     Appleton, Mrs. Edward Dale (Charlotte Lamson)  female  53
# 10                           Astor, Col. John Jacob    male  47

# %%
# Another way you can sort specific rows and columns using the loc method 
tit.loc[0:10 ][['name','sex','age']]
# Out:
#                                                name     sex     age
# 0                     Allen, Miss. Elisabeth Walton  female      29
# 1                    Allison, Master. Hudson Trevor    male  0.9167
# 2                      Allison, Miss. Helen Loraine  female       2
# 3              Allison, Mr. Hudson Joshua Creighton    male      30
# 4   Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female      25
# 5                               Anderson, Mr. Harry    male      48
# 6                 Andrews, Miss. Kornelia Theodosia  female      63
# 7                            Andrews, Mr. Thomas Jr    male      39
# 8     Appleton, Mrs. Edward Dale (Charlotte Lamson)  female      53
# 9                           Artagaveytia, Mr. Ramon    male      71
# 10                           Astor, Col. John Jacob    male      47

# %% [markdown]
# # using iloc in selecting preferred rows and columns

# %%
houses['bedrooms'].value_counts().sort_values(ascending=True)
# Out:
# 11       1
# 33       1
# 10       3
# 9        6
# 0       13
# 8       13
# 7       38
# 1      199
# 6      272
# 5     1601
# 2     2760
# 4     6882
# 3     9824
# Name: bedrooms, dtype: int64

# %%
houses.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
houses['bedrooms'].value_counts().iloc[0:10]
# Out:
# 3    9824
# 4    6882
# 2    2760
# 5    1601
# 6     272
# 1     199
# 7      38
# 0      13
# 8      13
# 9       6
# Name: bedrooms, dtype: int64

# %% [markdown]
# # Filtering data using boolean
# # Equal to comparison(==)

# %%
df = tit.head()
df
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#       age  sibsp  parch  ticket      fare    cabin embarked boat body  \
# 0      29      0      0   24160  211.3375       B5        S    2    ?
# 1  0.9167      1      2  113781    151.55  C22 C26        S   11    ?
# 2       2      1      2  113781    151.55  C22 C26        S    ?    ?
# 3      30      1      2  113781    151.55  C22 C26        S    ?  135
# 4      25      1      2  113781    151.55  C22 C26        S    ?    ?
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %%
df['sex']== 'female'
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# Name: sex, dtype: bool

# %%
df[df['sex']== 'female']
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#   age  sibsp  parch  ticket      fare    cabin embarked boat body  \
# 0  29      0      0   24160  211.3375       B5        S    2    ?
# 2   2      1      2  113781    151.55  C22 C26        S    ?    ?
# 4  25      1      2  113781    151.55  C22 C26        S    ?    ?
#
#                          home.dest
# 0                     St Louis, MO
# 2  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %%
df['survived'] == 1
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# 4    False
# Name: survived, dtype: bool

# %%
# we use ==(double equals) to select a particular data in a dataframe 
# but i have to pay detail attention to types 
df[df['survived'] == 1]
# Out:
#    pclass  survived                            name     sex     age  sibsp  \
# 0       1         1   Allen, Miss. Elisabeth Walton  female      29      0
# 1       1         1  Allison, Master. Hudson Trevor    male  0.9167      1
#
#    parch  ticket      fare    cabin embarked boat body  \
# 0      0   24160  211.3375       B5        S    2    ?
# 1      2  113781    151.55  C22 C26        S   11    ?
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON

# %% [markdown]
# # Not equal to comparison (!=)

# %%
tit[tit['pclass'] != 1]['pclass'].value_counts().plot(kind='bar')
# so after we sort it out then we select the field then count 
#another way to write this code is 
#tit[tit.pclass != 1].pclass.value_counts()
# Out:
# <AxesSubplot:>

# %%
tit[tit['pclass'] != 1].head()
# Out:
#      pclass  survived                                   name     sex age  \
# 323       2         0                    Abelson, Mr. Samuel    male  30
# 324       2         1  Abelson, Mrs. Samuel (Hannah Wizosky)  female  28
# 325       2         0         Aldworth, Mr. Charles Augustus    male  30
# 326       2         0             Andrew, Mr. Edgardo Samuel    male  18
# 327       2         0               Andrew, Mr. Frank Thomas    male  25
#
#      sibsp  parch      ticket  fare cabin embarked boat body  \
# 323      1      0   P/PP 3381    24     ?        C    ?    ?
# 324      1      0   P/PP 3381    24     ?        C   10    ?
# 325      0      0      248744    13     ?        S    ?    ?
# 326      0      0      231945  11.5     ?        S    ?    ?
# 327      0      0  C.A. 34050  10.5     ?        S    ?    ?
#
#                                     home.dest
# 323                       Russia New York, NY
# 324                       Russia New York, NY
# ...

# %% [markdown]
# # Greater than, Less than or equal to comparison(>)

# %%
hos[hos['price']>5000000]
# Out:
#               id             date      price  bedrooms  bathrooms  \
# 1164  1247600105  20141020T000000  5110800.0         5       5.25
# 1315  7558700030  20150413T000000  5300000.0         6       6.00
# 1448  8907500070  20150413T000000  5350000.0         5       5.00
# 3914  9808700762  20140611T000000  7062500.0         5       4.50
# 4411  2470100110  20140804T000000  5570000.0         5       5.75
# 7252  6762700020  20141013T000000  7700000.0         6       8.00
# 9254  9208900037  20140919T000000  6885000.0         6       7.75
#
#       sqft_living  sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 1164         8010     45517     2.0           1     4  ...     12        5990
# 1315         7390     24829     2.0           1     4  ...     12        5000
# 1448         8000     23985     2.0           0     4  ...     12        6720
# 3914        10040     37325     2.0           1     2  ...     11        7680
# ...

# %%
hos[hos['bedrooms']>10]
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 8757   1773100755  20140821T000000  520000.0        11       3.00
# 15870  2402100895  20140625T000000  640000.0        33       1.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 8757          3000      4960     2.0           0     0  ...      7
# 15870         1620      6000     1.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 8757         2400            600      1918          1999    98106  47.5560
# 15870        1040            580      1947             0    98103  47.6878
#
#           long  sqft_living15  sqft_lot15
# 8757  -122.363           1420        4960
# 15870 -122.331           1330        4700
#
# [2 rows x 21 columns]

# %%
hos[hos['bedrooms'] >= 10]
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 8757   1773100755  20140821T000000   520000.0        11       3.00
# 13314   627300145  20140814T000000  1148000.0        10       5.25
# 15161  5566100170  20141029T000000   650000.0        10       2.00
# 15870  2402100895  20140625T000000   640000.0        33       1.75
# 19254  8812401450  20141229T000000   660000.0        10       3.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 8757          3000      4960     2.0           0     0  ...      7
# 13314         4590     10920     1.0           0     2  ...      9
# 15161         3610     11914     2.0           0     0  ...      7
# 15870         1620      6000     1.0           0     0  ...      7
# 19254         2920      3745     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 8757         2400            600      1918          1999    98106  47.5560
# ...

# %% [markdown]
# # FILTERING USING BETWEEN(LEFT, RIGHT = BOTH INCLUSIVE)

# %%
hos[hos['bedrooms'].between(5,7)].head()
# Out:
#             id             date     price  bedrooms  bathrooms  sqft_living  \
# 14  1175000570  20150312T000000  530000.0         5       2.00         1810
# 22  7137970340  20140703T000000  285000.0         5       2.50         2270
# 42  7203220400  20140707T000000  861990.0         5       2.75         3595
# 51  7231300125  20150217T000000  345000.0         5       2.50         3150
# 54  4217401195  20150303T000000  920000.0         5       2.25         2730
#
#     sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 14      4850     1.5           0     0  ...      7        1810              0
# 22      6300     2.0           0     0  ...      8        2270              0
# 42      5639     2.0           0     0  ...      9        3595              0
# 51      9134     1.0           0     0  ...      8        1640           1510
# 54      6000     1.5           0     0  ...      8        2130            600
#
# ...

# %%
#if we wanna breakdown to know the exact numbers we add the field name.value_count()
hos[hos['bedrooms'].between(5,7)].bedrooms.value_counts()
# Out:
# 5    1601
# 6     272
# 7      38
# Name: bedrooms, dtype: int64

# %%
hos[hos['grade'].between(11,13)].grade.value_counts()
# Out:
# 11    399
# 12     90
# 13     13
# Name: grade, dtype: int64

# %% [markdown]
# # FILTERING A PARTICULAR COLLECTIOINS USING ISIN
# ### ISIN() is used where you wanna sort a particular data in a column

# %%
netflix.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
countries=['India', 'United States', 'South Africa']
netflix[netflix['country'].isin(countries)].head()
# Out:
#    show_id     type                 title         director  \
# 0       s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1       s2  TV Show         Blood & Water              NaN
# 4       s5  TV Show          Kota Factory              NaN
# 9      s10    Movie          The Starling   Theodore Melfi
# 15     s16  TV Show     Dear White People              NaN
#
#                                                  cast        country  \
# 0                                                 NaN  United States
# 1   Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 4   Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# 9   Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...  United States
# 15  Logan Browning, Brandon P. Bell, DeRon Horton,...  United States
#
#             date_added  release_year rating   duration  \
# 0   September 25, 2021          2020  PG-13     90 min
# 1   September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
#this is when youre sorting specific set of data in a column
rtype = ['PG-13','TV-MA','R']
director2 = ['kirsten Johnson','Theodore Melfi']
mask = netflix['rating'].isin(rtype)
mask2 = netflix['director'].isin(director2)
netflix[mask & mask2]
# Out:
#   show_id   type         title        director  \
# 9     s10  Movie  The Starling  Theodore Melfi
#
#                                                 cast        country  \
# 9  Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...  United States
#
#            date_added  release_year rating duration         listed_in  \
# 9  September 24, 2021          2021  PG-13  104 min  Comedies, Dramas
#
#                                          description
# 9  A woman adjusting to life after a loss contend...

# %%
wc = ['Theodore Melfi']
netflix[netflix['director'].isin(wc)]
# Out:
#   show_id   type         title        director  \
# 9     s10  Movie  The Starling  Theodore Melfi
#
#                                                 cast        country  \
# 9  Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...  United States
#
#            date_added  release_year rating duration         listed_in  \
# 9  September 24, 2021          2021  PG-13  104 min  Comedies, Dramas
#
#                                          description
# 9  A woman adjusting to life after a loss contend...

# %% [markdown]
# # COMBINING CONDITIONS WHEN FILTERING
# #### WE FILTERING COMBINED CONDITIONS USING AND(&)

# %%
women = titanic['sex'] == 'female'
died = titanic['survived'] == 0
titanic[women & died]
# Out:
#                                                     pclass  survived     sex  \
# name
# Allison, Miss. Helen Loraine                             1         0  female
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)          1         0  female
# Evans, Miss. Edith Corse                                 1         0  female
# Isham, Miss. Ann Elizabeth                               1         0  female
# Straus, Mrs. Isidor (Rosalie Ida Blun)                   1         0  female
# Carter, Mrs. Ernest Courtenay (Lilian Hughes)            2         0  female
# Chapman, Mrs. John Henry (Sara Elizabeth Lawry)          2         0  female
# Corbett, Mrs. Walter H (Irene Colvin)                    2         0  female
# Corey, Mrs. Percy C (Mary Phyllis Elizabeth Mil...       2         0  female
# Funk, Miss. Annie Clemmer                                2         0  female
# Hiltunen, Miss. Marta                                    2         0  female
# ...

# %% [markdown]
# # Another way to do comparision with two different condition

# %%
houses[(houses['waterfront'] == 1) & (houses['price'] < 500000)]
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 264    2123039032  20141027T000000  369900.0         1       0.75
# 1168   3523029041  20141009T000000  290000.0         2       0.75
# 1949   1922039062  20150420T000000  480000.0         2       1.50
# 3829   8550001515  20141001T000000  429592.0         2       2.75
# 6102    222029026  20140917T000000  340000.0         2       0.75
# 8277    221029019  20150428T000000  400000.0         3       2.50
# 8450    121039042  20150313T000000  425000.0         3       2.75
# 11556  2013802030  20140911T000000  357000.0         3       2.00
# 14827  2423029009  20140617T000000  465000.0         2       2.00
# 16570  2923039243  20141113T000000  340000.0         4       1.00
# 18275  2781600195  20141117T000000  285000.0         1       1.00
# 18848  7631800110  20140918T000000  380000.0         3       2.50
# 19002  5216200090  20140616T000000  385000.0         2       1.00
#
# ...

# %%
views = houses['view'] == 4
grades = houses['grade'] >= 11
houses[views & grades].head()
# Out:
#               id             date      price  bedrooms  bathrooms  \
# 540    622049114  20150218T000000  2125000.0         3       2.50
# 1164  1247600105  20141020T000000  5110800.0         5       5.25
# 1315  7558700030  20150413T000000  5300000.0         6       6.00
# 1448  8907500070  20150413T000000  5350000.0         5       5.00
# 2085  8106100105  20141114T000000  3850000.0         4       4.25
#
#       sqft_living  sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 540          5403     24069     2.0           1     4  ...     12        5403
# 1164         8010     45517     2.0           1     4  ...     12        5990
# 1315         7390     24829     2.0           1     4  ...     12        5000
# 1448         8000     23985     2.0           0     4  ...     12        6720
# 2085         5770     21300     2.0           1     4  ...     11        5770
#
#       sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
#combining more conditions
views = houses['view'] == 4
grades = houses['grade'] >= 11
smaller = houses['sqft_living'] <= 3000
houses[views & grades & smaller].head()
# Out:
#              id             date      price  bedrooms  bathrooms  sqft_living  \
# 4013  724069059  20140509T000000  2400000.0         3       2.25         3000
#
#       sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 4013     11665     1.5           1     4  ...     11        3000
#
#       sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 4013              0      2001             0    98075  47.5884 -122.086
#
#       sqft_living15  sqft_lot15
# 4013           3000       15959
#
# [1 rows x 21 columns]

# %% [markdown]
# # COMBINING CONDITIONS USING OR

# %%
built = houses['yr_built'] >= 2014
renovated = houses['yr_renovated'] >= 2014
recent = houses[built | renovated]
recent.sort_values('yr_renovated', ascending= True).head()
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 42     7203220400  20140707T000000   861990.0         5       2.75
# 20563   715010110  20140804T000000  1240420.0         5       3.25
# 20567  6926700654  20140921T000000   700000.0         2       2.00
# 20569  8895800110  20140805T000000  1299890.0         5       4.00
# 20576  3277801592  20140925T000000   479950.0         3       2.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 42            3595      5639     2.0           0     0  ...      9
# 20563         5790     13726     2.0           0     3  ...     10
# 20567         1490       713     3.0           0     0  ...      9
# 20569         3870      5929     2.0           0     0  ...     10
# 20576         1820      1358     3.0           0     0  ...      9
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 42           3595              0      2014             0    98053  47.6848
# ...

# %%
nameD = ['David Fincher']
nameF = ['Martin Scorsese']
Dave = netflix['director'].isin(nameD)
Martins = netflix['director'].isin(nameF)
netflix[Dave | Martins].head()
# Out:
#      show_id   type                         title         director  \
# 600     s601  Movie                      The Game    David Fincher
# 1358   s1359  Movie                Shutter Island  Martin Scorsese
# 1595   s1596  Movie                          MANK    David Fincher
# 2632   s2633  Movie  No Direction Home: Bob Dylan  Martin Scorsese
# 2860   s2861  Movie                          Hugo  Martin Scorsese
#
#                                                    cast  \
# 600   Michael Douglas, Sean Penn, Deborah Kara Unger...
# 1358  Leonardo DiCaprio, Mark Ruffalo, Ben Kingsley,...
# 1595  Gary Oldman, Amanda Seyfried, Charles Dance, L...
# 2632  Bob Dylan, Joan Baez, Dave Van Ronk, Peter Yar...
# 2860  Ben Kingsley, Sacha Baron Cohen, Asa Butterfie...
#
#                                     country        date_added  release_year  \
# 600                           United States      July 1, 2021          1997
# ...

# %% [markdown]
# # COMPARISON USING AND / OR

# %%
nameD = ['David Fincher']
nameF = ['Martin Scorsese']
Dave = netflix['director'].isin(nameD)
Martins = netflix['director'].isin(nameF)
rec = netflix['release_year'] > 2010
# afterwards we group them by functions >>> True or False
FN =netflix[(Dave | Martins) & rec]
# I sorted the release year 
FN.sort_values('release_year')
# Out:
#      show_id   type                                              title  \
# 2860   s2861  Movie                                               Hugo
# 8320   s8321  Movie                    The Girl with the Dragon Tattoo
# 3227   s3228  Movie                                       The Irishman
# 3759   s3760  Movie  Rolling Thunder Revue: A Bob Dylan Story by Ma...
# 1595   s1596  Movie                                               MANK
#
#              director                                               cast  \
# 2860  Martin Scorsese  Ben Kingsley, Sacha Baron Cohen, Asa Butterfie...
# 8320    David Fincher  Daniel Craig, Rooney Mara, Christopher Plummer...
# 3227  Martin Scorsese  Robert De Niro, Al Pacino, Joe Pesci, Harvey K...
# 3759  Martin Scorsese  Bob Dylan, Allen Ginsberg, Joan Baez, Patti Sm...
# 1595    David Fincher  Gary Oldman, Amanda Seyfried, Charles Dance, L...
#
#                                     country         date_added  release_year  \
# ...

# %%
# Another way to do this 
netflix[netflix['director'].isin(['David Fincher','Martin Scorsese'])].head()
# Out:
#      show_id   type                         title         director  \
# 600     s601  Movie                      The Game    David Fincher
# 1358   s1359  Movie                Shutter Island  Martin Scorsese
# 1595   s1596  Movie                          MANK    David Fincher
# 2632   s2633  Movie  No Direction Home: Bob Dylan  Martin Scorsese
# 2860   s2861  Movie                          Hugo  Martin Scorsese
#
#                                                    cast  \
# 600   Michael Douglas, Sean Penn, Deborah Kara Unger...
# 1358  Leonardo DiCaprio, Mark Ruffalo, Ben Kingsley,...
# 1595  Gary Oldman, Amanda Seyfried, Charles Dance, L...
# 2632  Bob Dylan, Joan Baez, Dave Van Ronk, Peter Yar...
# 2860  Ben Kingsley, Sacha Baron Cohen, Asa Butterfie...
#
#                                     country        date_added  release_year  \
# 600                           United States      July 1, 2021          1997
# ...

# %% [markdown]
# # BITWISE NEGATION
# ## To negate the output
# ### We use ~ (squiggle)

# %%
df = titanic.head()
wom = df['sex'] == 'female'
df[~ wom]
# Out:
#                                       pclass  survived   sex     age  sibsp  \
# name
# Allison, Master. Hudson Trevor             1         1  male  0.9167      1
# Allison, Mr. Hudson Joshua Creighton       1         0  male      30      1
#
#                                       parch  ticket    fare    cabin embarked  \
# name
# Allison, Master. Hudson Trevor            2  113781  151.55  C22 C26        S
# Allison, Mr. Hudson Joshua Creighton      2  113781  151.55  C22 C26        S
#
#                                      boat body  \
# name
# Allison, Master. Hudson Trevor         11    ?
# Allison, Mr. Hudson Joshua Creighton    ?  135
#
#                                                             home.dest
# name
# Allison, Master. Hudson Trevor        Montreal, PQ / Chesterville, ON
# Allison, Mr. Hudson Joshua Creighton  Montreal, PQ / Chesterville, ON

# %%
built = houses['yr_built'] >= 2014
renovated = houses['yr_renovated'] >= 2014
recent = built | renovated
houses[recent]
houses[~recent].head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
nameD = ['David Fincher']
nameF = ['Martin Scorsese']
Dave = netflix['director'].isin(nameD)
Martins = netflix['director'].isin(nameF)
netflix[~(Dave | Martins)].head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# # ISNA METHOD IS USED TO PRINT OUT NAN VALUES

# %%
netflix[netflix['director'].isna()].head()
# Out:
#    show_id     type                                title director  \
# 1       s2  TV Show                        Blood & Water      NaN
# 3       s4  TV Show                Jailbirds New Orleans      NaN
# 4       s5  TV Show                         Kota Factory      NaN
# 10     s11  TV Show  Vendetta: Truth, Lies and The Mafia      NaN
# 14     s15  TV Show      Crime Stories: India Detectives      NaN
#
#                                                  cast       country  \
# 1   Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa
# 3                                                 NaN           NaN
# 4   Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...         India
# 10                                                NaN           NaN
# 14                                                NaN           NaN
#
#             date_added  release_year rating   duration  \
# 1   September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
netflix[netflix['director'].isna() & netflix['cast'].isna()].head()
# Out:
#    show_id     type                                title director cast  \
# 3       s4  TV Show                Jailbirds New Orleans      NaN  NaN
# 10     s11  TV Show  Vendetta: Truth, Lies and The Mafia      NaN  NaN
# 14     s15  TV Show      Crime Stories: India Detectives      NaN  NaN
# 66     s67  TV Show        Raja Rasoi Aur Anya Kahaniyan      NaN  NaN
# 69     s70  TV Show       Stories by Rabindranath Tagore      NaN  NaN
#
#    country          date_added  release_year rating  duration  \
# 3      NaN  September 24, 2021          2021  TV-MA  1 Season
# 10     NaN  September 24, 2021          2021  TV-MA  1 Season
# 14     NaN  September 22, 2021          2021  TV-MA  1 Season
# 66   India  September 15, 2021          2014   TV-G  1 Season
# 69   India  September 15, 2021          2015  TV-PG  1 Season
#
#                                             listed_in  \
# 3                              Docuseries, Reality TV
# ...

# %% [markdown]
# # notna(will print out values without nan values>> which means its got value)

# %%
netflix[netflix['director'].notna() & netflix['cast'].notna()].head()
# we can incorporate the bitwise negation principle to get the opposite of the method
# Out:
#   show_id     type                             title  \
# 2      s3  TV Show                         Ganglands
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
#
#                         director  \
# 2                Julien Leclercq
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
#
#                                                 cast  \
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...
# 6  Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 7  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
#
#                                              country          date_added  \
# ...

# %% [markdown]
# # FILTERING + PLOTTING EXAMPLES

# %%
titanic[titanic['sex'] == 'female'].survived.value_counts()
# Out:
# 1    339
# 0    127
# Name: survived, dtype: int64

# %%
women = titanic['sex'] == 'female'
titanic[women].survived.value_counts().plot(kind= 'bar')
# at this juncture you can use bitwise negation to tweak the data output
# Out:
# <AxesSubplot:>

# %%
houses[houses['price'] > 3000000].zipcode.value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # DROPPING COLUMNS

# %%
# we use this method to drop the entire columns or rows if not needed
# Afterwards we specify by using axis to demonstrate that its rows or columns 
btc.drop(labels=['SNo','Date'], axis=1)
# We can also make it another way
btc.drop(columns=['SNo','Date']).head()
# Out:
#            Name        High         Low        Open       Close  Volume  \
# Symbol
# BTC     Bitcoin  147.488007  134.000000  134.444000  144.539993     0.0
# BTC     Bitcoin  146.929993  134.050003  144.000000  139.000000     0.0
# BTC     Bitcoin  139.889999  107.720001  139.000000  116.989998     0.0
# BTC     Bitcoin  125.599998   92.281898  116.379997  105.209999     0.0
# BTC     Bitcoin  108.127998   79.099998  106.250000   97.750000     0.0
#
#            Marketcap
# Symbol
# BTC     1.603769e+09
# BTC     1.542813e+09
# BTC     1.298955e+09
# BTC     1.168517e+09
# BTC     1.085995e+09

# %% [markdown]
# # DROPPING ROWS

# %%
country.head()
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Afghanistan           South Asia         2.523
# Zimbabwe      Sub-Saharan Africa         3.145
# Rwanda        Sub-Saharan Africa         3.415
# Botswana      Sub-Saharan Africa         3.467
# Lesotho       Sub-Saharan Africa         3.512
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Afghanistan                            0.038         2.596         2.449
# Zimbabwe                               0.058         3.259         3.030
# Rwanda                                 0.068         3.548         3.282
# Botswana                               0.074         3.611         3.322
# Lesotho                                0.120         3.748         3.276
#
#               Logged GDP per capita  Social support  Healthy life expectancy  \
# Country name
# Afghanistan                   7.695           0.463                   52.493
# ...

# %%
country.drop(labels='Denmark', axis=0).head()
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Afghanistan           South Asia         2.523
# Zimbabwe      Sub-Saharan Africa         3.145
# Rwanda        Sub-Saharan Africa         3.415
# Botswana      Sub-Saharan Africa         3.467
# Lesotho       Sub-Saharan Africa         3.512
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Afghanistan                            0.038         2.596         2.449
# Zimbabwe                               0.058         3.259         3.030
# Rwanda                                 0.068         3.548         3.282
# Botswana                               0.074         3.611         3.322
# Lesotho                                0.120         3.748         3.276
#
#               Logged GDP per capita  Social support  Healthy life expectancy  \
# Country name
# Afghanistan                   7.695           0.463                   52.493
# ...

# %% [markdown]
# # Deleting a chunk of rows

# %%
country.drop(['Rwanda','Botswana','Zimbabwe']).head()
# Out:
#                        Regional indicator  Ladder score  \
# Country name
# Afghanistan                    South Asia         2.523
# Lesotho                Sub-Saharan Africa         3.512
# Malawi                 Sub-Saharan Africa         3.600
# Haiti         Latin America and Caribbean         3.615
# Tanzania               Sub-Saharan Africa         3.623
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Afghanistan                            0.038         2.596         2.449
# Lesotho                                0.120         3.748         3.276
# Malawi                                 0.092         3.781         3.419
# Haiti                                  0.173         3.953         3.276
# Tanzania                               0.071         3.762         3.485
#
#               Logged GDP per capita  Social support  Healthy life expectancy  \
# Country name
# ...

# %% [markdown]
# # DROPPING BY POSITION

# %%
country.drop(country.index[0:3]).head()
# Out:
#                        Regional indicator  Ladder score  \
# Country name
# Botswana               Sub-Saharan Africa         3.467
# Lesotho                Sub-Saharan Africa         3.512
# Malawi                 Sub-Saharan Africa         3.600
# Haiti         Latin America and Caribbean         3.615
# Tanzania               Sub-Saharan Africa         3.623
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Botswana                               0.074         3.611         3.322
# Lesotho                                0.120         3.748         3.276
# Malawi                                 0.092         3.781         3.419
# Haiti                                  0.173         3.953         3.276
# Tanzania                               0.071         3.762         3.485
#
#               Logged GDP per capita  Social support  Healthy life expectancy  \
# Country name
# ...

# %% [markdown]
# # ADDING NEW STATIC COLUMN

# %%
#this is how we add new columns like selecting a series 
titanic['species'] = 'human'
titanic.head()
# Out:
#                                                  pclass  survived     sex  \
# name
# Allen, Miss. Elisabeth Walton                         1         1  female
# Allison, Master. Hudson Trevor                        1         1    male
# Allison, Miss. Helen Loraine                          1         0  female
# Allison, Mr. Hudson Joshua Creighton                  1         0    male
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)       1         0  female
#
#                                                     age  sibsp  parch  ticket  \
# name
# Allen, Miss. Elisabeth Walton                        29      0      0   24160
# Allison, Master. Hudson Trevor                   0.9167      1      2  113781
# Allison, Miss. Helen Loraine                          2      1      2  113781
# Allison, Mr. Hudson Joshua Creighton                 30      1      2  113781
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)      25      1      2  113781
#
# ...

# %%
# you can change the location of the column by using insert
houses.insert(0, 'Try','King County')

# %% [markdown]
# # ASSIGNING EXISTING FIEL VALUES TO ANOTHER FIELD

# %%
# So you have to assign the name to the series existing already 
houses['Sale_Price'] = houses['price']
houses.head()
# Out:
#            Try          id             date     price  bedrooms  bathrooms  \
# 0  King County  7129300520  20141013T000000  221900.0         3       1.00
# 1  King County  6414100192  20141209T000000  538000.0         3       2.25
# 2  King County  5631500400  20150225T000000  180000.0         2       1.00
# 3  King County  2487200875  20141209T000000  604000.0         4       3.00
# 4  King County  1954400510  20150218T000000  510000.0         3       2.00
#
#    sqft_living  sqft_lot  floors  waterfront  ...  sqft_above  sqft_basement  \
# 0         1180      5650     1.0           0  ...        1180              0
# 1         2570      7242     2.0           0  ...        2170            400
# 2          770     10000     1.0           0  ...         770              0
# 3         1960      5000     1.0           0  ...        1050            910
# 4         1680      8080     1.0           0  ...        1680              0
#
# ...

# %%
# this is positioning the field to your preferred loc
houses.insert(3, 'num_bedrooms', houses['bedrooms'])

# %%
houses.head()
# Out:
#            Try          id             date  num_bedrooms     price  bedrooms  \
# 0  King County  7129300520  20141013T000000             3  221900.0         3
# 1  King County  6414100192  20141209T000000             3  538000.0         3
# 2  King County  5631500400  20150225T000000             2  180000.0         2
# 3  King County  2487200875  20141209T000000             4  604000.0         4
# 4  King County  1954400510  20150218T000000             3  510000.0         3
#
#    bathrooms  sqft_living  sqft_lot  floors  ...  sqft_above  sqft_basement  \
# 0       1.00         1180      5650     1.0  ...        1180              0
# 1       2.25         2570      7242     2.0  ...        2170            400
# 2       1.00          770     10000     1.0  ...         770              0
# 3       3.00         1960      5000     1.0  ...        1050            910
# 4       2.00         1680      8080     1.0  ...        1680              0
#
# ...

# %% [markdown]
# # ADDING OR CREATING DYNAMIC COLUMNS

# %%
titanic.drop(columns=['species'], inplace=True)

# %%
#this is one way to add a dynamic columns after tweeking 
famsum = titanic['sibsp'] + titanic['parch']
#you can do it this way when inserting to the last
titanic['family'] = famsum
# or give it a preferred position this way 
titanic.insert(4, 'family2', famsum)
titanic.head()
# Out:
#                                                  pclass  survived     sex  \
# name
# Allen, Miss. Elisabeth Walton                         1         1  female
# Allison, Master. Hudson Trevor                        1         1    male
# Allison, Miss. Helen Loraine                          1         0  female
# Allison, Mr. Hudson Joshua Creighton                  1         0    male
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)       1         0  female
#
#                                                     age  family2  sibsp  \
# name
# Allen, Miss. Elisabeth Walton                        29        0      0
# Allison, Master. Hudson Trevor                   0.9167        3      1
# Allison, Miss. Helen Loraine                          2        3      1
# Allison, Mr. Hudson Joshua Creighton                 30        3      1
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)      25        3      1
#
# ...

# %%
#SORTINT TO KNOW THE FAMILY WITH THE HIGHEST NUMBER 
titanic.sort_values('family',ascending=False).head()
# Out:
#                               pclass  survived     sex age  family2  sibsp  \
# name
# Sage, Mr. Frederick                3         0    male   ?       10      8
# Sage, Mr. John George              3         0    male   ?       10      1
# Sage, Miss. Constance Gladys       3         0  female   ?       10      8
# Sage, Master. Thomas Henry         3         0    male   ?       10      8
# Sage, Miss. Ada                    3         0  female   ?       10      8
#
#                               parch    ticket   fare cabin embarked boat body  \
# name
# Sage, Mr. Frederick               2  CA. 2343  69.55     ?        S    ?    ?
# Sage, Mr. John George             9  CA. 2343  69.55     ?        S    ?    ?
# Sage, Miss. Constance Gladys      2  CA. 2343  69.55     ?        S    ?    ?
# Sage, Master. Thomas Henry        2  CA. 2343  69.55     ?        S    ?    ?
# Sage, Miss. Ada                   2  CA. 2343  69.55     ?        S    ?    ?
#
# ...

# %%
#SORTING TO KNOW THE FAMILY WHO SURVIVED 
titanic[titanic['survived'] == 1].sort_values('family',ascending=False).head()
# Out:
#                                                     pclass  survived     sex  \
# name
# Asplund, Master. Edvin Rojj Felix                        3         1    male
# Andersson, Miss. Erna Alexandra                          3         1  female
# Asplund, Mrs. Carl Oscar (Selma Augusta Emilia ...       3         1  female
# Asplund, Miss. Lillian Gertrud                           3         1  female
# Fortune, Miss. Alice Elizabeth                           1         1  female
#
#                                                    age  family2  sibsp  parch  \
# name
# Asplund, Master. Edvin Rojj Felix                    3        6      4      2
# Andersson, Miss. Erna Alexandra                     17        6      4      2
# Asplund, Mrs. Carl Oscar (Selma Augusta Emilia ...  38        6      1      5
# Asplund, Miss. Lillian Gertrud                       5        6      4      2
# Fortune, Miss. Alice Elizabeth                      24        5      3      2
#
# ...

# %%
#FINDING PEOPLE WHO TRAVELLED ALONE AND THEIR sex
solo_pas=titanic['family'] == 0
titanic[solo_pas].sex.value_counts().plot(kind ='pie')
# Out:
# <AxesSubplot:ylabel='sex'>

# %% [markdown]
# # INSERTING A COLUMN WHICH IS PRICE per SQFT

# %%
houses['PRICE_SQFT']= houses['price']/ houses['sqft_living']
houses.head()
# Out:
#            Try          id             date  num_bedrooms     price  bedrooms  \
# 0  King County  7129300520  20141013T000000             3  221900.0         3
# 1  King County  6414100192  20141209T000000             3  538000.0         3
# 2  King County  5631500400  20150225T000000             2  180000.0         2
# 3  King County  2487200875  20141209T000000             4  604000.0         4
# 4  King County  1954400510  20150218T000000             3  510000.0         3
#
#    bathrooms  sqft_living  sqft_lot  floors  ...  sqft_basement  yr_built  \
# 0       1.00         1180      5650     1.0  ...              0      1955
# 1       2.25         2570      7242     2.0  ...            400      1951
# 2       1.00          770     10000     1.0  ...              0      1933
# 3       3.00         1960      5000     1.0  ...            910      1965
# 4       2.00         1680      8080     1.0  ...              0      1987
#
# ...

# %%
houses.sort_values('PRICE_SQFT', ascending= False).head(50)['zipcode'].value_counts().plot(kind ='barh')
# Out:
# <AxesSubplot:>

# %%
btc['Change']=btc['Close'] - btc['Open']
btc.sort_values('Change', ascending=False).head(10)
# Out:
#          SNo     Name                 Date          High           Low  \
# Symbol
# BTC     2843  Bitcoin  2021-02-08 23:59:59  46203.931437  38076.322807
# BTC     2920  Bitcoin  2021-04-26 23:59:59  54288.002155  48852.796843
# BTC     2864  Bitcoin  2021-03-01 23:59:59  49784.015290  45115.093115
# BTC     2854  Bitcoin  2021-02-19 23:59:59  56113.650547  50937.275722
# BTC     2924  Bitcoin  2021-04-30 23:59:59  57900.719988  53129.600877
# BTC     2929  Bitcoin  2021-05-05 23:59:59  57911.363597  52969.055363
# BTC     2944  Bitcoin  2021-05-20 23:59:59  42462.984986  35050.615825
# BTC     2948  Bitcoin  2021-05-24 23:59:59  39835.139830  34551.080550
# BTC     2964  Bitcoin  2021-06-09 23:59:59  37537.371150  32475.866031
# BTC     2876  Bitcoin  2021-03-13 23:59:59  61683.864014  56217.972382
#
#                 Open         Close        Volume     Marketcap       Change
# Symbol
# BTC     38886.827290  46196.463719  1.014672e+11  8.603427e+11  7309.636429
# ...

# %%
btc.sort_values('Change', ascending=False).head(10)['Change'].plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='Change'>

# %%
houses[['Try','id']]
# Out:
# <bound method DataFrame.value_counts of                Try          id
# 0      King County  7129300520
# 1      King County  6414100192
# 2      King County  5631500400
# 3      King County  2487200875
# 4      King County  1954400510
# 5      King County  7237550310
# 6      King County  1321400060
# 7      King County  2008000270
# 8      King County  2414600126
# 9      King County  3793500160
# 10     King County  1736800520
# 11     King County  9212900260
# 12     King County   114101516
# 13     King County  6054650070
# 14     King County  1175000570
# 15     King County  9297300055
# 16     King County  1875500060
# 17     King County  6865200140
# 18     King County    16000397
# 19     King County  7983200060
# 20     King County  6300500875
# 21     King County  2524049179
# 22     King County  7137970340
# 23     King County  8091400200
# 24     King County  3814700200
# ...            ...         ...
# 21588  King County  2767600688
# 21589  King County  7570050450
# ...
